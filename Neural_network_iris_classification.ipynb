# %% [markdown]
# <a href="https://colab.research.google.com/github/syx1990/deep-learning/blob/main/Neural_network_iris_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
# !/usr/bin/python3
# author by : yuxiangShi
# tell  by: 18538187569
# desc by: 基于神经网络的鸢尾花分类

# 1.导入包
import tensorflow as tf
import numpy as np
from sklearn import datasets

print(tf.__version__)

# 2.导入训练数据
load_iris = datasets.load_iris() 
# 3.提炼特征和标签
x_train = load_iris.data
y_train = load_iris.target
# 4.搭建模型，及搭建神经网络
#全连接层网络结构（激活函数为softmax；正则化为l2）
model = tf.keras.models.Sequential([
                                    tf.keras.layers.Dense(3,activation='softmax',kernel_regularizer=tf.keras.regularizers.l2())
                                    ])
# 配置神经网络的训练方法，优化器为sgd；loss损失函数为；metrics评测指标为：y_是数值，y是独热码
model.compile(optimizer=tf.keras.optimizers.SGD(lr=0.1),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['sparse_categorical_accuracy'])
# 5.训练模型
# 执行训练过程，validation_split=从训练集中划分多少比列给测试集；validation_freq每多少次epoch迭代使用测试集验证一次结果
model.fit(x_train,y_train,batch_size=32,epochs=500,validation_split=0.2,validation_freq=20)

# 6.测试模型
# 打印和统计
model.summary()
# Out:
# 2.6.0
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/500
# 4/4 [==============================] - 1s 4ms/step - loss: 1.6324 - sparse_categorical_accuracy: 0.6583
# Epoch 2/500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7790 - sparse_categorical_accuracy: 0.7250
# Epoch 3/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5298 - sparse_categorical_accuracy: 0.8417
# Epoch 4/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5344 - sparse_categorical_accuracy: 0.7917
# Epoch 5/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7681 - sparse_categorical_accuracy: 0.7833
# Epoch 6/500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5236 - sparse_categorical_accuracy: 0.8750
# Epoch 7/500
# ...
